# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

fig = plt.figure()
fig.suptitle('livestock', fontsize=14, fontweight='bold')
ax = fig.add_subplot()

x1 = np.linspace(-1.0, 10.0, 100)
y1 = np.linspace(25.0, 25.0, 100)
ax.plot(x1, y1, linestyle = '--', linewidth = 2, color = '0.1')

x1 = np.linspace(-1.0, 10.0, 100)
y1 = np.linspace(50.0, 50.0, 100)
ax.plot(x1, y1, linestyle = '--', linewidth = 2, color = '0.1')

x1 = np.linspace(-1.0, 10.0, 100)
y1 = np.linspace(75.0, 75.0, 100)
ax.plot(x1, y1, linestyle = '--', linewidth = 2, color = '0.1')

data_names = ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
data_values = [100, 100, 100, 100, 100, 100, 100, 100, 100]

xs = range(len(data_names))


plt.bar([x + 0.05 for x in xs], 100, width = 0.75, color = 'green', alpha = 1, label = 'wat', zorder = 2)
plt.xticks(xs, data_names)

data_percento = [93, 95, 95, 95, 95, 95, 95, 95, 96]

plt.bar([x + 0.05 for x in xs], data_percento, width = 0.75, color = 'grey', alpha = 1, label = 'wat', zorder = 2)

data_percentt = [84, 86, 86, 86, 85, 84, 84, 84, 84]

plt.bar([x + 0.05 for x in xs], data_percentt, width = 0.75, color = 'blue', alpha = 1, label = 'wat', zorder = 2)
plt.xticks(xs, data_names)

data_percenttr = [60, 68, 63, 59, 58, 57, 67, 63, 63]

plt.bar([x + 0.05 for x in xs], data_percenttr, width = 0.75, color = 'orange', alpha = 1, label = 'wat', zorder = 2)

data_percenttr = [60, 67, 63, 59, 58, 57, 67, 63, 63]

plt.bar([x + 0.05 for x in xs], data_percenttr, width = 0.75, color = 'orange', alpha = 1, label = 'wat', zorder = 2)

data_percenttr = [47, 51, 50, 48, 47, 36, 50, 48, 48]

plt.bar([x + 0.05 for x in xs], data_percenttr, width = 0.75, color = 'pink', alpha = 1, label = 'wat', zorder = 2)

data_percentf = [36, 49, 48, 46, 45, 33, 45, 46, 46]

plt.bar([x + 0.05 for x in xs], data_percentf, width = 0.75, color = 'brown', alpha = 1, label = 'wat', zorder = 2)

ax.set_xlabel('water')
ax.set_ylabel('percent')

ax.text(0, 96, '7', style='normal', fontsize=10)
ax.text(1, 96, '5', style='normal', fontsize=10)
ax.text(2, 96, '5', style='normal', fontsize=10)
ax.text(3, 96, '5', style='normal', fontsize=10)
ax.text(4, 96, '5', style='normal', fontsize=10)
ax.text(5, 96, '5', style='normal', fontsize=10)
ax.text(6, 96, '5', style='normal', fontsize=10)
ax.text(7, 96, '5', style='normal', fontsize=10)
ax.text(8, 96, '4', style='normal', fontsize=10)

ax.text(0, 87, '9', style='normal', fontsize=10)
ax.text(1, 87, '9', style='normal', fontsize=10)
ax.text(2, 87, '9', style='normal', fontsize=10)
ax.text(3, 87, '9', style='normal', fontsize=10)
ax.text(4, 87, '9', style='normal', fontsize=10)
ax.text(5, 87, '10', style='normal', fontsize=10)
ax.text(6, 87, '9', style='normal', fontsize=10)
ax.text(7, 87, '9', style='normal', fontsize=10)
ax.text(8, 87, '9', style='normal', fontsize=10)

ax.text(0, 77, '24', style='normal', fontsize=10)
ax.text(1, 77, '18', style='normal', fontsize=10)
ax.text(2, 77, '23', style='normal', fontsize=10)
ax.text(3, 77, '27', style='normal', fontsize=10)
ax.text(4, 77, '27', style='normal', fontsize=10)
ax.text(5, 77, '9', style='normal', fontsize=10)
ax.text(6, 77, '17', style='normal', fontsize=10)
ax.text(7, 77, '21', style='normal', fontsize=10)
ax.text(8, 77, '21', style='normal', fontsize=10)

ax.text(0, 53, '13', style='normal', fontsize=10)
ax.text(1, 58, '16', style='normal', fontsize=10)
ax.text(2, 55, '13', style='normal', fontsize=10)
ax.text(3, 52, '11', style='normal', fontsize=10)
ax.text(4, 52, '11', style='normal', fontsize=10)
ax.text(5, 47, '21', style='normal', fontsize=10)
ax.text(6, 58, '17', style='normal', fontsize=10)
ax.text(7, 53, '15', style='normal', fontsize=10)
ax.text(8, 53, '15', style='normal', fontsize=10)

ax.text(0, 43, '11', style='normal', fontsize=10)
ax.text(1, 49, '2', style='normal', fontsize=10)
ax.text(2, 47, '2', style='normal', fontsize=10)
ax.text(3, 45, '2', style='normal', fontsize=10)
ax.text(4, 45, '2', style='normal', fontsize=10)
ax.text(5, 33, '3', style='normal', fontsize=10)
ax.text(6, 46, '2', style='normal', fontsize=10)
ax.text(7, 45, '2', style='normal', fontsize=10)
ax.text(8, 45, '2', style='normal', fontsize=10)

ax.text(0, 20, '36', style='normal', fontsize=10)
ax.text(1, 20, '50', style='normal', fontsize=10)
ax.text(2, 20, '48', style='normal', fontsize=10)
ax.text(3, 20, '46', style='normal', fontsize=10)
ax.text(4, 20, '45', style='normal', fontsize=10)
ax.text(5, 20, '33', style='normal', fontsize=10)
ax.text(6, 20, '45', style='normal', fontsize=10)
ax.text(7, 20, '46', style='normal', fontsize=10)
ax.text(8, 20, '46', style='normal', fontsize=10)


plt.show()
